# %% [markdown]
# ## input and type conversion

# %%
userName = input("What is your name? ")
print("Hello,", userName)
# Out:
# What is your name?  Broom
# Hello, Broom

# %%
age = input("How old are you? ")
print(age)
# Out:
# How old are you?  829862496929246782768967249867248678497284678246789467982467869278469
# 829862496929246782768967249867248678497284678246789467982467869278469

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
print(age + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(age + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
ageText= "17"
ageNumber = int(ageText)
print(type(ageNumber))
print(ageNumber + 5)
# Out:
# <class 'int'>
# 22

# %%
priceText = "9.99"
priceNumber = float (priceText)
print(priceNumber * 4)
# Out:
# 39.96

# %%
print(type(priceNumber))
# Out:
# <class 'float'>

# %%
score = 1000
scoreText = str(score)
print("your score is ", scoreText)
# Out:
# your score is  1000

# %%
age = int(input("How old are you? "))
Age = age + 5
print(age)
print("your age in 5 years ", Age)
# Out:
# How old are you?  5
# 5
# your age in 5 years  10

# %%
price = float (input("How much does it cost? $"))
tax = price * 0.88
print("Tax is: $", tax)
# Out:
# How much does it cost? $ 8
# Tax is: $ 7.04

# %%
age = 17
print("I am " + str(age) + " years old")
# Out:
# I am 17 years old

# %%
age = int("seventeen")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 age = int("seventeen")
#
# ValueError: invalid literal for int() with base 10: 'seventeen'

# %%
birthYear = input("Year you were born? ")
age = 2026 - int(birthYear)
print(age)
# Out:
# Year you were born?  9
# 2017

# %%
price = int("9.99")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 price = int("9.99")
#
# ValueError: invalid literal for int() with base 10: '9.99'

# %%
price = float("9.99")

# %%
# Program: Age caclulator
# Author MR.M
# Purpose Ask the user their birth year and tell them their age this year

currentYear = 2026

birthyear = int(input("What year were you born? "))
age = currentYear - birthyear
print("Age: ", age)
# Out:
# What year were you born?  8
# Age:  2018
